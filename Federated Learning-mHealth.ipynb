# %% [markdown]
# ### Federated Learning using Neural Network  Algorithm with Stochastic Gradient Descent Optimizer

# %% [markdown]
# ### Installing Torch

# %% [markdown]
# PyTorch is a Python package that provides two high-level features:
# - Tensor computation (like NumPy) with strong GPU acceleration
# - Deep neural networks built on a tape-based autograd system
#
# You can reuse your favorite Python packages such as NumPy, SciPy, and Cython to extend PyTorch when needed.

# %%
# !pip install torch
# Out:
# Collecting torch
#   Downloading torch-1.7.0-cp37-none-macosx_10_9_x86_64.whl (108.0 MB)
#      |████████████████████████████████| 108.0 MB 25 kB/s  eta 0:00:01    |████████████▍                   | 41.9 MB 868 kB/s eta 0:01:17     |████████████▉                   | 43.2 MB 1.6 MB/s eta 0:00:41     |████████████████████████▏       | 81.5 MB 734 kB/s eta 0:00:37     |████████████████████████▎       | 82.0 MB 734 kB/s eta 0:00:36     |█████████████████████████████▍  | 99.2 MB 1.8 MB/s eta 0:00:05
# Requirement already satisfied: numpy in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from torch) (1.18.5)
# Collecting dataclasses
#   Downloading dataclasses-0.6-py3-none-any.whl (14 kB)
# Requirement already satisfied: future in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from torch) (0.16.0)
# Requirement already satisfied: typing-extensions in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from torch) (3.7.4.1)
# Installing collected packages: dataclasses, torch
# Successfully installed dataclasses-0.6 torch-1.7.0

# %% [markdown]
# ### Installing Syft

# %% [markdown]
# PySyft is a Python library for secure and private Deep Learning. PySyft decouples private data from model training, using Federated Learning, Differential Privacy, and Encrypted Computation (like Multi-Party Computation (MPC) and Homomorphic Encryption (HE)) within the main Deep Learning frameworks like PyTorch and TensorFlow.

# %%
# !pip install syft
# Out:
# Requirement already satisfied: torch in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (1.4.0)
# Requirement already satisfied: syft in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (0.2.9)
# Requirement already satisfied: requests-toolbelt==0.9.1 in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from syft) (0.9.1)
# Requirement already satisfied: shaloop==0.2.1-alpha.11 in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from syft) (0.2.1a11)
# Requirement already satisfied: flask-socketio~=4.2.1 in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from syft) (4.2.1)
# Requirement already satisfied: Pillow>=7.1.0 in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from syft) (8.0.1)
# Requirement already satisfied: psutil==5.7.0 in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from syft) (5.7.0)
# Requirement already satisfied: notebook==5.7.8 in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from syft) (5.7.8)
# Requirement already satisfied: importlib-resources~=1.5.0 in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from syft) (1.5.0)
# Requirement already satisfied: RestrictedPython~=5.0 in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from syft) (5.1)
# Requirement already satisfied: torchvision~=0.5.0 in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from syft) (0.5.0)
# Requirement already satisfied: msgpack~=1.0.0 in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from syft) (1.0.0)
# Requirement already satisfied: websockets~=8.1.0 in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from syft) (8.1)
# Requirement already satisfied: aiortc==0.9.28 in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from syft) (0.9.28)
# Requirement already satisfied: tblib~=1.6.0 in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from syft) (1.6.0)
# Requirement already satisfied: requests~=2.22.0 in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from syft) (2.22.0)
# Requirement already satisfied: numpy~=1.18.1 in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from syft) (1.18.5)
# Requirement already satisfied: syft-proto~=0.5.2 in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from syft) (0.5.3)
# Requirement already satisfied: websocket-client~=0.57.0 in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from syft) (0.57.0)
# Requirement already satisfied: tornado==4.5.3 in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from syft) (4.5.3)
# Requirement already satisfied: scipy~=1.4.1 in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from syft) (1.4.1)
# Requirement already satisfied: openmined.threepio==0.2.0 in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from syft) (0.2.0)
# Requirement already satisfied: lz4~=3.0.2 in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from syft) (3.0.2)
# Requirement already satisfied: phe~=1.4.0 in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from syft) (1.4.0)
# Requirement already satisfied: Flask~=1.1.1 in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from syft) (1.1.1)
# Requirement already satisfied: dill~=0.3.1 in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from syft) (0.3.1.1)
# Requirement already satisfied: cffi>=1 in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from shaloop==0.2.1-alpha.11->syft) (1.12.3)
# Requirement already satisfied: pycparser>=2 in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from shaloop==0.2.1-alpha.11->syft) (2.19)
# Requirement already satisfied: python-socketio>=4.3.0 in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from flask-socketio~=4.2.1->syft) (4.6.0)
# Requirement already satisfied: traitlets>=4.2.1 in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from notebook==5.7.8->syft) (4.3.3)
# Requirement already satisfied: Send2Trash in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from notebook==5.7.8->syft) (1.5.0)
# Requirement already satisfied: pyzmq>=17 in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from notebook==5.7.8->syft) (18.1.0)
# Requirement already satisfied: ipykernel in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from notebook==5.7.8->syft) (5.1.2)
# Requirement already satisfied: jinja2 in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from notebook==5.7.8->syft) (2.10.3)
# Requirement already satisfied: jupyter-core>=4.4.0 in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from notebook==5.7.8->syft) (4.5.0)
# Requirement already satisfied: nbformat in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from notebook==5.7.8->syft) (4.4.0)
# Requirement already satisfied: jupyter-client>=5.2.0 in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from notebook==5.7.8->syft) (5.3.3)
# Requirement already satisfied: nbconvert in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from notebook==5.7.8->syft) (5.6.0)
# Requirement already satisfied: terminado>=0.8.1 in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from notebook==5.7.8->syft) (0.8.2)
# Requirement already satisfied: prometheus-client in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from notebook==5.7.8->syft) (0.7.1)
# Requirement already satisfied: ipython-genutils in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from notebook==5.7.8->syft) (0.2.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from importlib-resources~=1.5.0->syft) (0.23)
# Requirement already satisfied: zipp>=0.4; python_version < "3.8" in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from importlib-resources~=1.5.0->syft) (0.6.0)
# Requirement already satisfied: six in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from torchvision~=0.5.0->syft) (1.12.0)
# Requirement already satisfied: aioice<0.7.0,>=0.6.17 in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from aiortc==0.9.28->syft) (0.6.18)
# Requirement already satisfied: crc32c in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from aiortc==0.9.28->syft) (2.2)
# Requirement already satisfied: av<9.0.0,>=8.0.0 in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from aiortc==0.9.28->syft) (8.0.2)
# Requirement already satisfied: pyee>=6.0.0 in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from aiortc==0.9.28->syft) (7.0.4)
# Requirement already satisfied: pylibsrtp>=0.5.6 in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from aiortc==0.9.28->syft) (0.6.7)
# Requirement already satisfied: cryptography>=2.2 in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from aiortc==0.9.28->syft) (2.7)
# Requirement already satisfied: idna<2.9,>=2.5 in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from requests~=2.22.0->syft) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from requests~=2.22.0->syft) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from requests~=2.22.0->syft) (1.24.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from requests~=2.22.0->syft) (2019.9.11)
# Requirement already satisfied: protobuf>=3.12.2 in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from syft-proto~=0.5.2->syft) (3.13.0)
# Requirement already satisfied: click>=5.1 in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from Flask~=1.1.1->syft) (7.0)
# Requirement already satisfied: Werkzeug>=0.15 in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from Flask~=1.1.1->syft) (0.16.0)
# Requirement already satisfied: itsdangerous>=0.24 in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from Flask~=1.1.1->syft) (1.1.0)
# Requirement already satisfied: python-engineio>=3.13.0 in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from python-socketio>=4.3.0->flask-socketio~=4.2.1->syft) (3.13.2)
# Requirement already satisfied: decorator in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from traitlets>=4.2.1->notebook==5.7.8->syft) (4.4.0)
# Requirement already satisfied: ipython>=5.0.0 in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from ipykernel->notebook==5.7.8->syft) (7.8.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from jinja2->notebook==5.7.8->syft) (1.1.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from nbformat->notebook==5.7.8->syft) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.1 in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from jupyter-client>=5.2.0->notebook==5.7.8->syft) (2.8.0)
# Requirement already satisfied: bleach in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook==5.7.8->syft) (3.1.0)
# Requirement already satisfied: defusedxml in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook==5.7.8->syft) (0.6.0)
# Requirement already satisfied: pygments in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook==5.7.8->syft) (2.4.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook==5.7.8->syft) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook==5.7.8->syft) (1.4.2)
# Requirement already satisfied: entrypoints>=0.2.2 in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook==5.7.8->syft) (0.3)
# Requirement already satisfied: testpath in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook==5.7.8->syft) (0.4.2)
# Requirement already satisfied: more-itertools in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from zipp>=0.4; python_version < "3.8"->importlib-resources~=1.5.0->syft) (7.2.0)
# Requirement already satisfied: netifaces in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from aioice<0.7.0,>=0.6.17->aiortc==0.9.28->syft) (0.10.9)
# Requirement already satisfied: asn1crypto>=0.21.0 in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from cryptography>=2.2->aiortc==0.9.28->syft) (1.0.1)
# Requirement already satisfied: setuptools in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from protobuf>=3.12.2->syft-proto~=0.5.2->syft) (41.4.0)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel->notebook==5.7.8->syft) (4.7.0)
# Requirement already satisfied: appnope; sys_platform == "darwin" in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel->notebook==5.7.8->syft) (0.1.0)
# Requirement already satisfied: backcall in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel->notebook==5.7.8->syft) (0.1.0)
# Requirement already satisfied: jedi>=0.10 in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel->notebook==5.7.8->syft) (0.15.1)
# Requirement already satisfied: pickleshare in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel->notebook==5.7.8->syft) (0.7.5)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel->notebook==5.7.8->syft) (2.0.10)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook==5.7.8->syft) (0.15.4)
# Requirement already satisfied: attrs>=17.4.0 in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook==5.7.8->syft) (19.3.0)
# Requirement already satisfied: webencodings in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from bleach->nbconvert->notebook==5.7.8->syft) (0.5.1)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from pexpect; sys_platform != "win32"->ipython>=5.0.0->ipykernel->notebook==5.7.8->syft) (0.6.0)
# Requirement already satisfied: parso>=0.5.0 in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from jedi>=0.10->ipython>=5.0.0->ipykernel->notebook==5.7.8->syft) (0.5.1)
# Requirement already satisfied: wcwidth in /Users/tresnamf/opt/anaconda3/lib/python3.7/site-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=5.0.0->ipykernel->notebook==5.7.8->syft) (0.1.7)

# %% [markdown]
# ### Import some python library
# - Import `torch.nn.functional` for Rectified Linear Unit (ReLU) from torch
# - Import `torch.optim` for Stochastic Gradient Descent Optimizer
# - import `syft` for simulate federated learning

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import logging
import syft as sy

# %% [markdown]
# ### Use Hook Pytorch
# `Torch Hook`, for adding extra functionalities to support Federated Learning and other private AI tools.
# This experiment simulated 8 federated members as Virtual Worker

# %%
# hook PyTorch to PySyft i.e. add extra functionalities to support Federated Learning
# and other private AI tools
hook = sy.TorchHook(torch) 

# we create two imaginary schools
worker1 = sy.VirtualWorker(hook, id="worker1")
worker2 = sy.VirtualWorker(hook, id="worker2")
worker3 = sy.VirtualWorker(hook, id="worker3")
worker4 = sy.VirtualWorker(hook, id="worker4")
worker5 = sy.VirtualWorker(hook, id="worker5")
worker6 = sy.VirtualWorker(hook, id="worker6")
worker7 = sy.VirtualWorker(hook, id="worker7")
worker8 = sy.VirtualWorker(hook, id="worker8")

# %% [markdown]
# ### Initial parameter
# - Setting parameter of batch size, epochs, learning rate, cuda, device, number of workers and etc

# %%
class Arguments():
    def __init__(self):
        self.batch_size = 64
        self.test_batch_size = 1000
        self.epochs = 10
        self.lr = 0.01
        self.momentum = 0.5
        self.no_cuda = False
        self.seed = 1
        self.log_interval = 10
        self.save_model = False

args = Arguments()

use_cuda = not args.no_cuda and torch.cuda.is_available()

torch.manual_seed(args.seed)

device = torch.device("cuda" if use_cuda else "cpu")

kwargs = {'num_workers': 8, 'pin_memory': True} if use_cuda else {}

# %% [markdown]
# ### Prepare and Import multiple file CSV
# - Import `pandas` for manipulating, accessing, query dataset
# - Import `glob` for reading multiple file
# This experiment used 10 CSV files which contain 21 features and labels (six classes), with the name `mHealth_subject*.csv`.
#
# The dataset recorded the health activity from sensors. Each file contains the samples (by rows) recorded for all sensors (by columns). The labels used to identify the activities are similar to the ones.
# - Column 1: acceleration from the chest sensor (X axis)
# - Column 2: acceleration from the chest sensor (Y axis)
# - Column 3: acceleration from the chest sensor (Z axis)
# - Column 4: acceleration from the left-ankle sensor (X axis)
# - Column 5: acceleration from the left-ankle sensor (Y axis)
# - Column 6: acceleration from the left-ankle sensor (Z axis)
# - Column 7: gyro from the left-ankle sensor (X axis)
# - Column 8: gyro from the left-ankle sensor (Y axis)
# - Column 9: gyro from the left-ankle sensor (Z axis)
# - Column 10: magnetometer from the left-ankle sensor (X axis)
# - Column 11: magnetometer from the left-ankle sensor (Y axis)
# - Column 12: magnetometer from the left-ankle sensor (Z axis)
# - Column 13: acceleration from the right-lower-arm sensor (X axis)
# - Column 14: acceleration from the right-lower-arm sensor (Y axis)
# - Column 15: acceleration from the right-lower-arm sensor (Z axis)
# - Column 16: gyro from the right-lower-arm sensor (X axis)
# - Column 17: gyro from the right-lower-arm sensor (Y axis)
# - Column 18: gyro from the right-lower-arm sensor (Z axis)
# - Column 19: magnetometer from the right-lower-arm sensor (X axis)
# - Column 20: magnetometer from the right-lower-arm sensor (Y axis)
# - Column 21: magnetometer from the right-lower-arm sensor (Z axis)
# - Column 22: Label (0 for the null class)
#
# The preprocessed data has 6 labels of activity. The activity set is listed as follows:
# - L1: Standing still (1 min)
# - L2: Sitting and relaxing (1 min)
# - L3: Lying down (1 min)
# - L4: Walking (1 min)
# - L5: Climbing stairs (1 min)
# - L6: Running (1 min)
#
# After all the samples were imported, the process continued to split the training data and testing data. Finally, the dataset all ready to be used by 8 workers in the next step, the following code `inputs.shape process` showed `torch.Size([114123, 21])`, it explains that the number of samples is 114.123 and the number of columns is 21.

# %%
import pandas as pd
import numpy as np
import glob
import csv

#path = "drive/MyColab/emotional_dataset/angry_txt/"
#allFiles = glob.glob(os.path.join(path,"*.wav.txt"))

for filename in glob.glob('data/*.csv'):
  #print (filename)
      with open(filename, newline='') as f_input:
            fulltrainset = pd.read_csv(f_input,sep=',')
            X=fulltrainset.iloc[:,0:21]
            X=X.astype(np.float32)
            inputs = torch.tensor(X.values)
            y=fulltrainset.iloc[:,21]
            labels = torch.tensor(y.values)

            #X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

            # splitting training and test data
            pct_test = 0.2
            train_labels = labels[:-int(len(labels)*pct_test)]
            train_inputs = inputs[:-int(len(labels)*pct_test)]
            test_labels = labels[-int(len(labels)*pct_test):]
            test_inputs = inputs[-int(len(labels)*pct_test):]

inputs.shape
# Out:
# torch.Size([114123, 21])

# %% [markdown]
# ### Divide 8 workers to receive workload of training data and testing data
# This experiment used 8 virtual workers and each worker will receive 1/8 of training and testing data. `sy.BaseDataset` is used to read the split dataset and then send to each worker.

# %%
# threshold indexes for dataset split
train_idx = int(len(train_labels)/8)
test_idx = int(len(test_labels)/8)

# Sending toy datasets to virtual workers
worker1_train_dataset = sy.BaseDataset(train_inputs[:train_idx], 
                                  train_labels[:train_idx]).send(worker1)
worker2_train_dataset = sy.BaseDataset(train_inputs[train_idx:], 
                                    train_labels[train_idx:]).send(worker2)
worker3_train_dataset = sy.BaseDataset(train_inputs[train_idx:], 
                                    train_labels[train_idx:]).send(worker3)
worker4_train_dataset = sy.BaseDataset(train_inputs[train_idx:], 
                                    train_labels[train_idx:]).send(worker4)
worker5_train_dataset = sy.BaseDataset(train_inputs[train_idx:], 
                                    train_labels[train_idx:]).send(worker5)
worker6_train_dataset = sy.BaseDataset(train_inputs[train_idx:], 
                                    train_labels[train_idx:]).send(worker6)
worker7_train_dataset = sy.BaseDataset(train_inputs[train_idx:], 
                                    train_labels[train_idx:]).send(worker7)
worker8_train_dataset = sy.BaseDataset(train_inputs[train_idx:], 
                                    train_labels[train_idx:]).send(worker8)
worker1_test_dataset = sy.BaseDataset(test_inputs[:test_idx], 
                                  test_labels[:test_idx]).send(worker1)
worker2_test_dataset = sy.BaseDataset(test_inputs[test_idx:], 
                                  test_labels[test_idx:]).send(worker2)
worker3_test_dataset = sy.BaseDataset(test_inputs[test_idx:], 
                                  test_labels[test_idx:]).send(worker3)
worker4_test_dataset = sy.BaseDataset(test_inputs[test_idx:], 
                                  test_labels[test_idx:]).send(worker4)
worker5_test_dataset = sy.BaseDataset(test_inputs[test_idx:], 
                                  test_labels[test_idx:]).send(worker5)
worker6_test_dataset = sy.BaseDataset(test_inputs[test_idx:], 
                                  test_labels[test_idx:]).send(worker6)
worker7_test_dataset = sy.BaseDataset(test_inputs[test_idx:], 
                                  test_labels[test_idx:]).send(worker7)
worker8_test_dataset = sy.BaseDataset(test_inputs[test_idx:], 
                                  test_labels[test_idx:]).send(worker8)

# %% [markdown]
# ### Create federated dataset and data loader
# `sy.FederatedDataset` is used to create federated Dataset which it is extension of Pytorch dataset class, while `sy.FederatedDataLoader` is used to cerate federated dataloaders, which it is extension of pytorch dataloader class

# %%
# Creating federated datasets, an extension of Pytorch TensorDataset class
federated_train_dataset = sy.FederatedDataset([worker1_train_dataset, worker2_train_dataset,worker3_train_dataset,
                                               worker4_train_dataset,worker5_train_dataset, worker6_train_dataset,
                                               worker7_train_dataset, worker8_train_dataset
                                              ])
federated_test_dataset = sy.FederatedDataset([worker1_test_dataset, worker2_test_dataset,
                                             worker3_test_dataset, worker4_test_dataset,
                                             worker5_test_dataset, worker6_test_dataset,
                                             worker7_test_dataset, worker8_test_dataset
                                             ])

# Creating federated dataloaders, an extension of Pytorch DataLoader class
federated_train_loader = sy.FederatedDataLoader(federated_train_dataset, 
                                                batch_size=args.batch_size, shuffle=True, **kwargs)
federated_test_loader = sy.FederatedDataLoader(federated_test_dataset, 
                                               batch_size=args.batch_size, shuffle=True, **kwargs)

# %% [markdown]
# #### Create Neural Network Model with Stochastic Gradient Descent Optimizer
# This experiment used Neural Network Model with Stochastic Gradient Descent Optimizer, which it need to set up the input, hidden and output layer. The following code `class torch.nn.Linear(in_features: int, out_features: int, bias: bool = True)`, explain that the neural network has the number of feature input and out features.
#
# In the forward process, `x.view(-1, 21).squeeze(0)` explain that Neural Network receive the 2D input in pytorch format
#
# To implement Stochastic Gradient Descent Optimizer in Neural Network, following code `optim.SGD(model.parameters(), lr=0.01)`

# %%
class Model(nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        self.fc1 = nn.Linear(21, 64)
        self.fc2 = nn.Linear(64, 10)

    def forward(self, x):
        x = x.view(-1, 21).squeeze(0)
        x = self.fc1(x)
        x = F.relu(x)
        x = self.fc2(x)
        return F.log_softmax(x, dim=1)


model = Model()
optimizer = optim.SGD(model.parameters(), lr=0.01)

# %% [markdown]
# ### Building Model of mHealth Dataset
#
# Finally, mHealth dataset can be built in the predictive model using 8 Virtual Workers and also Neural Network Model with Stochastic Gradient Descent Optimizer
#
# This experiment used `epcoch`=5, and evaluated the model using `loss` parameter

# %%
for epoch in range(0, 5):
    model.train()
    for batch_idx, (data, target) in enumerate(federated_train_loader):
        # send the model to the client device where the data is present
        model.send(data.location)
        # training the model
        optimizer.zero_grad()
        output = model(data)
        loss = F.nll_loss(output, target)
        loss.backward()
        optimizer.step()
        # get back the improved model
        model.get()
        if batch_idx % 100 == 0:
            # get back the loss
            loss = loss.get()
            print('Epoch: {:2d} [{:5d}/{:5d} ({:3.0f}%)]\tLoss: {:.6f}'.format(
                epoch+1,
                batch_idx * 64,
                len(federated_train_loader) * 64,
                100. * batch_idx / len(federated_train_loader),
                loss.item()))
# Out:
# Epoch:  1 [    0/570624 (  0%)]	Loss: 2.874954
# Epoch:  1 [ 6400/570624 (  1%)]	Loss: 0.377007
# Epoch:  1 [12800/570624 (  2%)]	Loss: 0.787154
# Epoch:  1 [19200/570624 (  3%)]	Loss: 0.357691
# Epoch:  1 [25600/570624 (  4%)]	Loss: 0.385611
# Epoch:  1 [32000/570624 (  6%)]	Loss: 0.317974
# Epoch:  1 [38400/570624 (  7%)]	Loss: 0.440708
# Epoch:  1 [44800/570624 (  8%)]	Loss: 0.389026
# Epoch:  1 [51200/570624 (  9%)]	Loss: 0.481003
# Epoch:  1 [57600/570624 ( 10%)]	Loss: 0.302120
# Epoch:  1 [64000/570624 ( 11%)]	Loss: 0.500075
# Epoch:  1 [70400/570624 ( 12%)]	Loss: 0.454674
# Epoch:  1 [76800/570624 ( 13%)]	Loss: 0.362509
# Epoch:  1 [83200/570624 ( 15%)]	Loss: 0.177408
# Epoch:  1 [89600/570624 ( 16%)]	Loss: 0.314166
# Epoch:  1 [96000/570624 ( 17%)]	Loss: 0.257121
# Epoch:  1 [102400/570624 ( 18%)]	Loss: 0.395584
# Epoch:  1 [108800/570624 ( 19%)]	Loss: 0.385994
# Epoch:  1 [115200/570624 ( 20%)]	Loss: 0.285283
# Epoch:  1 [121600/570624 ( 21%)]	Loss: 0.346868
# Epoch:  1 [128000/570624 ( 22%)]	Loss: 0.189383
# Epoch:  1 [134400/570624 ( 24%)]	Loss: 0.282895
# Epoch:  1 [140800/570624 ( 25%)]	Loss: 0.244314
# Epoch:  1 [147200/570624 ( 26%)]	Loss: 0.268995
# Epoch:  1 [153600/570624 ( 27%)]	Loss: 0.247938
# Epoch:  1 [160000/570624 ( 28%)]	Loss: 0.327436
# Epoch:  1 [166400/570624 ( 29%)]	Loss: 0.181464
# Epoch:  1 [172800/570624 ( 30%)]	Loss: 0.273780
# Epoch:  1 [179200/570624 ( 31%)]	Loss: 0.456987
# Epoch:  1 [185600/570624 ( 33%)]	Loss: 0.290939
# Epoch:  1 [192000/570624 ( 34%)]	Loss: 0.257504
# Epoch:  1 [198400/570624 ( 35%)]	Loss: 0.175195
# Epoch:  1 [204800/570624 ( 36%)]	Loss: 0.260057
# Epoch:  1 [211200/570624 ( 37%)]	Loss: 0.195415
# Epoch:  1 [217600/570624 ( 38%)]	Loss: 0.189408
# Epoch:  1 [224000/570624 ( 39%)]	Loss: 0.303830
# Epoch:  1 [230400/570624 ( 40%)]	Loss: 0.146720
# Epoch:  1 [236800/570624 ( 41%)]	Loss: 0.335443
# Epoch:  1 [243200/570624 ( 43%)]	Loss: 0.221430
# Epoch:  1 [249600/570624 ( 44%)]	Loss: 0.214667
# Epoch:  1 [256000/570624 ( 45%)]	Loss: 0.199636
# Epoch:  1 [262400/570624 ( 46%)]	Loss: 0.225126
# Epoch:  1 [268800/570624 ( 47%)]	Loss: 0.161841
# Epoch:  1 [275200/570624 ( 48%)]	Loss: 0.137480
# Epoch:  1 [281600/570624 ( 49%)]	Loss: 0.243977
# Epoch:  1 [288000/570624 ( 50%)]	Loss: 0.236482
# Epoch:  1 [294400/570624 ( 52%)]	Loss: 0.242266
# Epoch:  1 [300800/570624 ( 53%)]	Loss: 0.157337
# Epoch:  1 [307200/570624 ( 54%)]	Loss: 0.264020
# Epoch:  1 [313600/570624 ( 55%)]	Loss: 0.278472
# Epoch:  1 [320000/570624 ( 56%)]	Loss: 0.166094
# Epoch:  1 [326400/570624 ( 57%)]	Loss: 0.190714
# Epoch:  1 [332800/570624 ( 58%)]	Loss: 0.277322
# Epoch:  1 [339200/570624 ( 59%)]	Loss: 0.269580
# Epoch:  1 [345600/570624 ( 61%)]	Loss: 0.149870
# Epoch:  1 [352000/570624 ( 62%)]	Loss: 0.232204
# Epoch:  1 [358400/570624 ( 63%)]	Loss: 0.156934
# Epoch:  1 [364800/570624 ( 64%)]	Loss: 0.271635
# Epoch:  1 [371200/570624 ( 65%)]	Loss: 0.235808
# Epoch:  1 [377600/570624 ( 66%)]	Loss: 0.198606
# Epoch:  1 [384000/570624 ( 67%)]	Loss: 0.457708
# Epoch:  1 [390400/570624 ( 68%)]	Loss: 0.168048
# Epoch:  1 [396800/570624 ( 70%)]	Loss: 0.274425
# Epoch:  1 [403200/570624 ( 71%)]	Loss: 0.289524
# Epoch:  1 [409600/570624 ( 72%)]	Loss: 0.273922
# Epoch:  1 [416000/570624 ( 73%)]	Loss: 0.315067
# Epoch:  1 [422400/570624 ( 74%)]	Loss: 0.301273
# Epoch:  1 [428800/570624 ( 75%)]	Loss: 0.356191
# Epoch:  1 [435200/570624 ( 76%)]	Loss: 0.288295
# Epoch:  1 [441600/570624 ( 77%)]	Loss: 0.245131
# Epoch:  1 [448000/570624 ( 79%)]	Loss: 0.294193
# Epoch:  1 [454400/570624 ( 80%)]	Loss: 0.310502
# Epoch:  1 [460800/570624 ( 81%)]	Loss: 0.412040
# Epoch:  1 [467200/570624 ( 82%)]	Loss: 0.238016
# Epoch:  1 [473600/570624 ( 83%)]	Loss: 0.221350
# Epoch:  1 [480000/570624 ( 84%)]	Loss: 0.283942
# Epoch:  1 [486400/570624 ( 85%)]	Loss: 0.249393
# Epoch:  1 [492800/570624 ( 86%)]	Loss: 0.077440
# Epoch:  1 [499200/570624 ( 87%)]	Loss: 0.198341
# Epoch:  1 [505600/570624 ( 89%)]	Loss: 0.098722
# Epoch:  1 [512000/570624 ( 90%)]	Loss: 0.133889
# Epoch:  1 [518400/570624 ( 91%)]	Loss: 0.143977
# Epoch:  1 [524800/570624 ( 92%)]	Loss: 0.239737
# Epoch:  1 [531200/570624 ( 93%)]	Loss: 0.178490
# Epoch:  1 [537600/570624 ( 94%)]	Loss: 0.208408
# Epoch:  1 [544000/570624 ( 95%)]	Loss: 0.257953
# Epoch:  1 [550400/570624 ( 96%)]	Loss: 0.225821
# Epoch:  1 [556800/570624 ( 98%)]	Loss: 0.241626
# Epoch:  1 [563200/570624 ( 99%)]	Loss: 0.360358
# Epoch:  1 [569600/570624 (100%)]	Loss: 0.142102
# Epoch:  2 [    0/570624 (  0%)]	Loss: 0.260209
# Epoch:  2 [ 6400/570624 (  1%)]	Loss: 0.295116
# Epoch:  2 [12800/570624 (  2%)]	Loss: 0.294482
# Epoch:  2 [19200/570624 (  3%)]	Loss: 0.135610
# Epoch:  2 [25600/570624 (  4%)]	Loss: 0.189929
# Epoch:  2 [32000/570624 (  6%)]	Loss: 0.278818
# Epoch:  2 [38400/570624 (  7%)]	Loss: 0.290727
# Epoch:  2 [44800/570624 (  8%)]	Loss: 0.167822
# Epoch:  2 [51200/570624 (  9%)]	Loss: 0.157621
# Epoch:  2 [57600/570624 ( 10%)]	Loss: 0.188023
# Epoch:  2 [64000/570624 ( 11%)]	Loss: 0.144248
# Epoch:  2 [70400/570624 ( 12%)]	Loss: 0.158882
# Epoch:  2 [76800/570624 ( 13%)]	Loss: 0.231367
# Epoch:  2 [83200/570624 ( 15%)]	Loss: 0.206133
# Epoch:  2 [89600/570624 ( 16%)]	Loss: 0.283239
# Epoch:  2 [96000/570624 ( 17%)]	Loss: 0.148225
# Epoch:  2 [102400/570624 ( 18%)]	Loss: 0.259815
# Epoch:  2 [108800/570624 ( 19%)]	Loss: 0.216519
# Epoch:  2 [115200/570624 ( 20%)]	Loss: 0.154487
# Epoch:  2 [121600/570624 ( 21%)]	Loss: 0.289728
# Epoch:  2 [128000/570624 ( 22%)]	Loss: 0.154142
# Epoch:  2 [134400/570624 ( 24%)]	Loss: 0.152250
# Epoch:  2 [140800/570624 ( 25%)]	Loss: 0.091813
# Epoch:  2 [147200/570624 ( 26%)]	Loss: 0.107291
# Epoch:  2 [153600/570624 ( 27%)]	Loss: 0.118923
# Epoch:  2 [160000/570624 ( 28%)]	Loss: 0.136298
# Epoch:  2 [166400/570624 ( 29%)]	Loss: 0.096243
# Epoch:  2 [172800/570624 ( 30%)]	Loss: 0.170140
# Epoch:  2 [179200/570624 ( 31%)]	Loss: 0.209172
# Epoch:  2 [185600/570624 ( 33%)]	Loss: 0.235554
# Epoch:  2 [192000/570624 ( 34%)]	Loss: 0.191640
# Epoch:  2 [198400/570624 ( 35%)]	Loss: 0.199809
# Epoch:  2 [204800/570624 ( 36%)]	Loss: 0.154409
# Epoch:  2 [211200/570624 ( 37%)]	Loss: 0.117634
# Epoch:  2 [217600/570624 ( 38%)]	Loss: 0.134648
# Epoch:  2 [224000/570624 ( 39%)]	Loss: 0.196523
# Epoch:  2 [230400/570624 ( 40%)]	Loss: 0.235939
# Epoch:  2 [236800/570624 ( 41%)]	Loss: 0.176545
# Epoch:  2 [243200/570624 ( 43%)]	Loss: 0.185928
# Epoch:  2 [249600/570624 ( 44%)]	Loss: 0.427041
# Epoch:  2 [256000/570624 ( 45%)]	Loss: 0.210828
# Epoch:  2 [262400/570624 ( 46%)]	Loss: 0.210826
# Epoch:  2 [268800/570624 ( 47%)]	Loss: 0.193078
# Epoch:  2 [275200/570624 ( 48%)]	Loss: 0.256801
# Epoch:  2 [281600/570624 ( 49%)]	Loss: 0.175186
# Epoch:  2 [288000/570624 ( 50%)]	Loss: 0.176223
# Epoch:  2 [294400/570624 ( 52%)]	Loss: 0.218528
# Epoch:  2 [300800/570624 ( 53%)]	Loss: 0.185834
# Epoch:  2 [307200/570624 ( 54%)]	Loss: 0.185025
# Epoch:  2 [313600/570624 ( 55%)]	Loss: 0.144949
# Epoch:  2 [320000/570624 ( 56%)]	Loss: 0.280753
# Epoch:  2 [326400/570624 ( 57%)]	Loss: 0.059324
# Epoch:  2 [332800/570624 ( 58%)]	Loss: 0.142832
# Epoch:  2 [339200/570624 ( 59%)]	Loss: 0.218360
# Epoch:  2 [345600/570624 ( 61%)]	Loss: 0.243480
# Epoch:  2 [352000/570624 ( 62%)]	Loss: 0.141649
# Epoch:  2 [358400/570624 ( 63%)]	Loss: 0.218474
# Epoch:  2 [364800/570624 ( 64%)]	Loss: 0.236720
# Epoch:  2 [371200/570624 ( 65%)]	Loss: 0.235320
# Epoch:  2 [377600/570624 ( 66%)]	Loss: 0.128489
# Epoch:  2 [384000/570624 ( 67%)]	Loss: 0.207629
# Epoch:  2 [390400/570624 ( 68%)]	Loss: 0.285502
# Epoch:  2 [396800/570624 ( 70%)]	Loss: 0.334420
# Epoch:  2 [403200/570624 ( 71%)]	Loss: 0.103510
# Epoch:  2 [409600/570624 ( 72%)]	Loss: 0.257833
# Epoch:  2 [416000/570624 ( 73%)]	Loss: 0.286569
# Epoch:  2 [422400/570624 ( 74%)]	Loss: 0.142203
# Epoch:  2 [428800/570624 ( 75%)]	Loss: 0.108601
# Epoch:  2 [435200/570624 ( 76%)]	Loss: 0.079373
# Epoch:  2 [441600/570624 ( 77%)]	Loss: 0.133071
# Epoch:  2 [448000/570624 ( 79%)]	Loss: 0.151787
# Epoch:  2 [454400/570624 ( 80%)]	Loss: 0.115626
# Epoch:  2 [460800/570624 ( 81%)]	Loss: 0.210747
# Epoch:  2 [467200/570624 ( 82%)]	Loss: 0.172360
# Epoch:  2 [473600/570624 ( 83%)]	Loss: 0.265193
# Epoch:  2 [480000/570624 ( 84%)]	Loss: 0.196424
# Epoch:  2 [486400/570624 ( 85%)]	Loss: 0.243532
# Epoch:  2 [492800/570624 ( 86%)]	Loss: 0.170370
# Epoch:  2 [499200/570624 ( 87%)]	Loss: 0.163861
# Epoch:  2 [505600/570624 ( 89%)]	Loss: 0.150198
# Epoch:  2 [512000/570624 ( 90%)]	Loss: 0.189993
# Epoch:  2 [518400/570624 ( 91%)]	Loss: 0.139086
# Epoch:  2 [524800/570624 ( 92%)]	Loss: 0.221472
# Epoch:  2 [531200/570624 ( 93%)]	Loss: 0.186678
# Epoch:  2 [537600/570624 ( 94%)]	Loss: 0.236355
# Epoch:  2 [544000/570624 ( 95%)]	Loss: 0.144573
# Epoch:  2 [550400/570624 ( 96%)]	Loss: 0.133385
# Epoch:  2 [556800/570624 ( 98%)]	Loss: 0.183066
# Epoch:  2 [563200/570624 ( 99%)]	Loss: 0.156611
# Epoch:  2 [569600/570624 (100%)]	Loss: 0.234210
# Epoch:  3 [    0/570624 (  0%)]	Loss: 0.288260
# Epoch:  3 [ 6400/570624 (  1%)]	Loss: 0.245620
# Epoch:  3 [12800/570624 (  2%)]	Loss: 0.168809
# Epoch:  3 [19200/570624 (  3%)]	Loss: 0.134672
# Epoch:  3 [25600/570624 (  4%)]	Loss: 0.154345
# Epoch:  3 [32000/570624 (  6%)]	Loss: 0.220465
# Epoch:  3 [38400/570624 (  7%)]	Loss: 0.197848
# Epoch:  3 [44800/570624 (  8%)]	Loss: 0.155348
# Epoch:  3 [51200/570624 (  9%)]	Loss: 0.191969
# Epoch:  3 [57600/570624 ( 10%)]	Loss: 0.156760
# Epoch:  3 [64000/570624 ( 11%)]	Loss: 0.119787
# Epoch:  3 [70400/570624 ( 12%)]	Loss: 0.143120
# Epoch:  3 [76800/570624 ( 13%)]	Loss: 0.181194
# Epoch:  3 [83200/570624 ( 15%)]	Loss: 0.221250
# Epoch:  3 [89600/570624 ( 16%)]	Loss: 0.212502
# Epoch:  3 [96000/570624 ( 17%)]	Loss: 0.183245
# Epoch:  3 [102400/570624 ( 18%)]	Loss: 0.155249
# Epoch:  3 [108800/570624 ( 19%)]	Loss: 0.263683
# Epoch:  3 [115200/570624 ( 20%)]	Loss: 0.204036
# Epoch:  3 [121600/570624 ( 21%)]	Loss: 0.137351
# Epoch:  3 [128000/570624 ( 22%)]	Loss: 0.144543
# Epoch:  3 [134400/570624 ( 24%)]	Loss: 0.177414
# Epoch:  3 [140800/570624 ( 25%)]	Loss: 0.195031
# Epoch:  3 [147200/570624 ( 26%)]	Loss: 0.131058
# Epoch:  3 [153600/570624 ( 27%)]	Loss: 0.206555
# Epoch:  3 [160000/570624 ( 28%)]	Loss: 0.194831
# Epoch:  3 [166400/570624 ( 29%)]	Loss: 0.251051
# Epoch:  3 [172800/570624 ( 30%)]	Loss: 0.164288
# Epoch:  3 [179200/570624 ( 31%)]	Loss: 0.131256
# Epoch:  3 [185600/570624 ( 33%)]	Loss: 0.130308
# Epoch:  3 [192000/570624 ( 34%)]	Loss: 0.189650
# Epoch:  3 [198400/570624 ( 35%)]	Loss: 0.152370
# Epoch:  3 [204800/570624 ( 36%)]	Loss: 0.117057
# Epoch:  3 [211200/570624 ( 37%)]	Loss: 0.197285
# Epoch:  3 [217600/570624 ( 38%)]	Loss: 0.124615
# Epoch:  3 [224000/570624 ( 39%)]	Loss: 0.227381
# Epoch:  3 [230400/570624 ( 40%)]	Loss: 0.158560
# Epoch:  3 [236800/570624 ( 41%)]	Loss: 0.228413
# Epoch:  3 [243200/570624 ( 43%)]	Loss: 0.122517
# Epoch:  3 [249600/570624 ( 44%)]	Loss: 0.145134
# Epoch:  3 [256000/570624 ( 45%)]	Loss: 0.162955
# Epoch:  3 [262400/570624 ( 46%)]	Loss: 0.204559
# Epoch:  3 [268800/570624 ( 47%)]	Loss: 0.216812
# Epoch:  3 [275200/570624 ( 48%)]	Loss: 0.241184
# Epoch:  3 [281600/570624 ( 49%)]	Loss: 0.173109
# Epoch:  3 [288000/570624 ( 50%)]	Loss: 0.170083
# Epoch:  3 [294400/570624 ( 52%)]	Loss: 0.300823
# Epoch:  3 [300800/570624 ( 53%)]	Loss: 0.214030
# Epoch:  3 [307200/570624 ( 54%)]	Loss: 0.413514
# Epoch:  3 [313600/570624 ( 55%)]	Loss: 0.175670
# Epoch:  3 [320000/570624 ( 56%)]	Loss: 0.130261
# Epoch:  3 [326400/570624 ( 57%)]	Loss: 0.171056
# Epoch:  3 [332800/570624 ( 58%)]	Loss: 0.128456
# Epoch:  3 [339200/570624 ( 59%)]	Loss: 0.195904
# Epoch:  3 [345600/570624 ( 61%)]	Loss: 0.133863
# Epoch:  3 [352000/570624 ( 62%)]	Loss: 0.068732
# Epoch:  3 [358400/570624 ( 63%)]	Loss: 0.192786
# Epoch:  3 [364800/570624 ( 64%)]	Loss: 0.144989
# Epoch:  3 [371200/570624 ( 65%)]	Loss: 0.130644
# Epoch:  3 [377600/570624 ( 66%)]	Loss: 0.151516
# Epoch:  3 [384000/570624 ( 67%)]	Loss: 0.140460
# Epoch:  3 [390400/570624 ( 68%)]	Loss: 0.096372
# Epoch:  3 [396800/570624 ( 70%)]	Loss: 0.191936
# Epoch:  3 [403200/570624 ( 71%)]	Loss: 0.261948
# Epoch:  3 [409600/570624 ( 72%)]	Loss: 0.165394
# Epoch:  3 [416000/570624 ( 73%)]	Loss: 0.116947
# Epoch:  3 [422400/570624 ( 74%)]	Loss: 0.221320
# Epoch:  3 [428800/570624 ( 75%)]	Loss: 0.144760
# Epoch:  3 [435200/570624 ( 76%)]	Loss: 0.101637
# Epoch:  3 [441600/570624 ( 77%)]	Loss: 0.177246
# Epoch:  3 [448000/570624 ( 79%)]	Loss: 0.200121
# Epoch:  3 [454400/570624 ( 80%)]	Loss: 0.160640
# Epoch:  3 [460800/570624 ( 81%)]	Loss: 0.119406
# Epoch:  3 [467200/570624 ( 82%)]	Loss: 0.114157
# Epoch:  3 [473600/570624 ( 83%)]	Loss: 0.148574
# Epoch:  3 [480000/570624 ( 84%)]	Loss: 0.274416
# Epoch:  3 [486400/570624 ( 85%)]	Loss: 0.214247
# Epoch:  3 [492800/570624 ( 86%)]	Loss: 0.118389
# Epoch:  3 [499200/570624 ( 87%)]	Loss: 0.178627
# Epoch:  3 [505600/570624 ( 89%)]	Loss: 0.169161
# Epoch:  3 [512000/570624 ( 90%)]	Loss: 0.133769
# Epoch:  3 [518400/570624 ( 91%)]	Loss: 0.255135
# Epoch:  3 [524800/570624 ( 92%)]	Loss: 0.189464
# Epoch:  3 [531200/570624 ( 93%)]	Loss: 0.156386
# Epoch:  3 [537600/570624 ( 94%)]	Loss: 0.157513
# Epoch:  3 [544000/570624 ( 95%)]	Loss: 0.126302
# Epoch:  3 [550400/570624 ( 96%)]	Loss: 0.267129
# Epoch:  3 [556800/570624 ( 98%)]	Loss: 0.196936
# Epoch:  3 [563200/570624 ( 99%)]	Loss: 0.086786
# Epoch:  3 [569600/570624 (100%)]	Loss: 0.154076
# Epoch:  4 [    0/570624 (  0%)]	Loss: 0.449420
# Epoch:  4 [ 6400/570624 (  1%)]	Loss: 0.268225
# Epoch:  4 [12800/570624 (  2%)]	Loss: 0.136410
# Epoch:  4 [19200/570624 (  3%)]	Loss: 0.117643
# Epoch:  4 [25600/570624 (  4%)]	Loss: 0.087328
# Epoch:  4 [32000/570624 (  6%)]	Loss: 0.186148
# Epoch:  4 [38400/570624 (  7%)]	Loss: 0.152685
# Epoch:  4 [44800/570624 (  8%)]	Loss: 0.158511
# Epoch:  4 [51200/570624 (  9%)]	Loss: 0.147547
# Epoch:  4 [57600/570624 ( 10%)]	Loss: 0.220867
# Epoch:  4 [64000/570624 ( 11%)]	Loss: 0.185759
# Epoch:  4 [70400/570624 ( 12%)]	Loss: 0.104409
# Epoch:  4 [76800/570624 ( 13%)]	Loss: 0.186538
# Epoch:  4 [83200/570624 ( 15%)]	Loss: 0.168966
# Epoch:  4 [89600/570624 ( 16%)]	Loss: 0.247145
# Epoch:  4 [96000/570624 ( 17%)]	Loss: 0.111055
# Epoch:  4 [102400/570624 ( 18%)]	Loss: 0.176028
# Epoch:  4 [108800/570624 ( 19%)]	Loss: 0.152684
# Epoch:  4 [115200/570624 ( 20%)]	Loss: 0.250502
# Epoch:  4 [121600/570624 ( 21%)]	Loss: 0.167705
# Epoch:  4 [128000/570624 ( 22%)]	Loss: 0.242344
# Epoch:  4 [134400/570624 ( 24%)]	Loss: 0.059487
# Epoch:  4 [140800/570624 ( 25%)]	Loss: 0.239370
# Epoch:  4 [147200/570624 ( 26%)]	Loss: 0.091102
# Epoch:  4 [153600/570624 ( 27%)]	Loss: 0.180252
# Epoch:  4 [160000/570624 ( 28%)]	Loss: 0.203506
# Epoch:  4 [166400/570624 ( 29%)]	Loss: 0.135677
# Epoch:  4 [172800/570624 ( 30%)]	Loss: 0.276459
# Epoch:  4 [179200/570624 ( 31%)]	Loss: 0.086714
# Epoch:  4 [185600/570624 ( 33%)]	Loss: 0.184717
# Epoch:  4 [192000/570624 ( 34%)]	Loss: 0.098903
# Epoch:  4 [198400/570624 ( 35%)]	Loss: 0.272965
# Epoch:  4 [204800/570624 ( 36%)]	Loss: 0.179524
# Epoch:  4 [211200/570624 ( 37%)]	Loss: 0.166228
# Epoch:  4 [217600/570624 ( 38%)]	Loss: 0.237476
# Epoch:  4 [224000/570624 ( 39%)]	Loss: 0.038481
# Epoch:  4 [230400/570624 ( 40%)]	Loss: 0.177357
# Epoch:  4 [236800/570624 ( 41%)]	Loss: 0.219481
# Epoch:  4 [243200/570624 ( 43%)]	Loss: 0.173547
# Epoch:  4 [249600/570624 ( 44%)]	Loss: 0.317798
# Epoch:  4 [256000/570624 ( 45%)]	Loss: 0.143523
# Epoch:  4 [262400/570624 ( 46%)]	Loss: 0.244554
# Epoch:  4 [268800/570624 ( 47%)]	Loss: 0.176498
# Epoch:  4 [275200/570624 ( 48%)]	Loss: 0.124759
# Epoch:  4 [281600/570624 ( 49%)]	Loss: 0.101721
# Epoch:  4 [288000/570624 ( 50%)]	Loss: 0.136859
# Epoch:  4 [294400/570624 ( 52%)]	Loss: 0.209363
# Epoch:  4 [300800/570624 ( 53%)]	Loss: 0.234846
# Epoch:  4 [307200/570624 ( 54%)]	Loss: 0.211145
# Epoch:  4 [313600/570624 ( 55%)]	Loss: 0.123330
# Epoch:  4 [320000/570624 ( 56%)]	Loss: 0.263966
# Epoch:  4 [326400/570624 ( 57%)]	Loss: 0.151942
# Epoch:  4 [332800/570624 ( 58%)]	Loss: 0.117965
# Epoch:  4 [339200/570624 ( 59%)]	Loss: 0.137448
# Epoch:  4 [345600/570624 ( 61%)]	Loss: 0.184067
# Epoch:  4 [352000/570624 ( 62%)]	Loss: 0.061309
# Epoch:  4 [358400/570624 ( 63%)]	Loss: 0.114194
# Epoch:  4 [364800/570624 ( 64%)]	Loss: 0.127373
# Epoch:  4 [371200/570624 ( 65%)]	Loss: 0.094475
# Epoch:  4 [377600/570624 ( 66%)]	Loss: 0.084754
# Epoch:  4 [384000/570624 ( 67%)]	Loss: 0.134054
# Epoch:  4 [390400/570624 ( 68%)]	Loss: 0.171574
# Epoch:  4 [396800/570624 ( 70%)]	Loss: 0.192674
# Epoch:  4 [403200/570624 ( 71%)]	Loss: 0.110076
# Epoch:  4 [409600/570624 ( 72%)]	Loss: 0.196489
# Epoch:  4 [416000/570624 ( 73%)]	Loss: 0.258694
# Epoch:  4 [422400/570624 ( 74%)]	Loss: 0.125119
# Epoch:  4 [428800/570624 ( 75%)]	Loss: 0.121489
# Epoch:  4 [435200/570624 ( 76%)]	Loss: 0.220789
# Epoch:  4 [441600/570624 ( 77%)]	Loss: 0.331936
# Epoch:  4 [448000/570624 ( 79%)]	Loss: 0.159945
# Epoch:  4 [454400/570624 ( 80%)]	Loss: 0.177111
# Epoch:  4 [460800/570624 ( 81%)]	Loss: 0.151385
# Epoch:  4 [467200/570624 ( 82%)]	Loss: 0.252017
# Epoch:  4 [473600/570624 ( 83%)]	Loss: 0.137664
# Epoch:  4 [480000/570624 ( 84%)]	Loss: 0.157663
# Epoch:  4 [486400/570624 ( 85%)]	Loss: 0.152533
# Epoch:  4 [492800/570624 ( 86%)]	Loss: 0.166943
# Epoch:  4 [499200/570624 ( 87%)]	Loss: 0.171547
# Epoch:  4 [505600/570624 ( 89%)]	Loss: 0.114931
# Epoch:  4 [512000/570624 ( 90%)]	Loss: 0.111399
# Epoch:  4 [518400/570624 ( 91%)]	Loss: 0.123781
# Epoch:  4 [524800/570624 ( 92%)]	Loss: 0.128330
# Epoch:  4 [531200/570624 ( 93%)]	Loss: 0.182952
# Epoch:  4 [537600/570624 ( 94%)]	Loss: 0.126265
# Epoch:  4 [544000/570624 ( 95%)]	Loss: 0.086662
# Epoch:  4 [550400/570624 ( 96%)]	Loss: 0.170262
# Epoch:  4 [556800/570624 ( 98%)]	Loss: 0.116746
# Epoch:  4 [563200/570624 ( 99%)]	Loss: 0.087391
# Epoch:  4 [569600/570624 (100%)]	Loss: 0.159201
# Epoch:  5 [    0/570624 (  0%)]	Loss: 0.247704
# Epoch:  5 [ 6400/570624 (  1%)]	Loss: 0.276355
# Epoch:  5 [12800/570624 (  2%)]	Loss: 0.152832
# Epoch:  5 [19200/570624 (  3%)]	Loss: 0.186258
# Epoch:  5 [25600/570624 (  4%)]	Loss: 0.071668
# Epoch:  5 [32000/570624 (  6%)]	Loss: 0.096981
# Epoch:  5 [38400/570624 (  7%)]	Loss: 0.172152
# Epoch:  5 [44800/570624 (  8%)]	Loss: 0.079489
# Epoch:  5 [51200/570624 (  9%)]	Loss: 0.084217
# Epoch:  5 [57600/570624 ( 10%)]	Loss: 0.068052
# Epoch:  5 [64000/570624 ( 11%)]	Loss: 0.255313
# Epoch:  5 [70400/570624 ( 12%)]	Loss: 0.109428
# Epoch:  5 [76800/570624 ( 13%)]	Loss: 0.123535
# Epoch:  5 [83200/570624 ( 15%)]	Loss: 0.094891
# Epoch:  5 [89600/570624 ( 16%)]	Loss: 0.175291
# Epoch:  5 [96000/570624 ( 17%)]	Loss: 0.105987
# Epoch:  5 [102400/570624 ( 18%)]	Loss: 0.152132
# Epoch:  5 [108800/570624 ( 19%)]	Loss: 0.152024
# Epoch:  5 [115200/570624 ( 20%)]	Loss: 0.119376
# Epoch:  5 [121600/570624 ( 21%)]	Loss: 0.144235
# Epoch:  5 [128000/570624 ( 22%)]	Loss: 0.126335
# Epoch:  5 [134400/570624 ( 24%)]	Loss: 0.148894
# Epoch:  5 [140800/570624 ( 25%)]	Loss: 0.183506
# Epoch:  5 [147200/570624 ( 26%)]	Loss: 0.161976
# Epoch:  5 [153600/570624 ( 27%)]	Loss: 0.108657
# Epoch:  5 [160000/570624 ( 28%)]	Loss: 0.206797
# Epoch:  5 [166400/570624 ( 29%)]	Loss: 0.156805
# Epoch:  5 [172800/570624 ( 30%)]	Loss: 0.256793
# Epoch:  5 [179200/570624 ( 31%)]	Loss: 0.133836
# Epoch:  5 [185600/570624 ( 33%)]	Loss: 0.141389
# Epoch:  5 [192000/570624 ( 34%)]	Loss: 0.124605
# Epoch:  5 [198400/570624 ( 35%)]	Loss: 0.201193
# Epoch:  5 [204800/570624 ( 36%)]	Loss: 0.097561
# Epoch:  5 [211200/570624 ( 37%)]	Loss: 0.164153
# Epoch:  5 [217600/570624 ( 38%)]	Loss: 0.167543
# Epoch:  5 [224000/570624 ( 39%)]	Loss: 0.226931
# Epoch:  5 [230400/570624 ( 40%)]	Loss: 0.144272
# Epoch:  5 [236800/570624 ( 41%)]	Loss: 0.192077
# Epoch:  5 [243200/570624 ( 43%)]	Loss: 0.172758
# Epoch:  5 [249600/570624 ( 44%)]	Loss: 0.176152
# Epoch:  5 [256000/570624 ( 45%)]	Loss: 0.195638
# Epoch:  5 [262400/570624 ( 46%)]	Loss: 0.184448
# Epoch:  5 [268800/570624 ( 47%)]	Loss: 0.117966
# Epoch:  5 [275200/570624 ( 48%)]	Loss: 0.225088
# Epoch:  5 [281600/570624 ( 49%)]	Loss: 0.105268
# Epoch:  5 [288000/570624 ( 50%)]	Loss: 0.126136
# Epoch:  5 [294400/570624 ( 52%)]	Loss: 0.203943
# Epoch:  5 [300800/570624 ( 53%)]	Loss: 0.140141
# Epoch:  5 [307200/570624 ( 54%)]	Loss: 0.203530
# Epoch:  5 [313600/570624 ( 55%)]	Loss: 0.189277
# Epoch:  5 [320000/570624 ( 56%)]	Loss: 0.187367
# Epoch:  5 [326400/570624 ( 57%)]	Loss: 0.177970
# Epoch:  5 [332800/570624 ( 58%)]	Loss: 0.157405
# Epoch:  5 [339200/570624 ( 59%)]	Loss: 0.100703
# Epoch:  5 [345600/570624 ( 61%)]	Loss: 0.191296
# Epoch:  5 [352000/570624 ( 62%)]	Loss: 0.132752
# Epoch:  5 [358400/570624 ( 63%)]	Loss: 0.165944
# Epoch:  5 [364800/570624 ( 64%)]	Loss: 0.167031
# Epoch:  5 [371200/570624 ( 65%)]	Loss: 0.164114
# Epoch:  5 [377600/570624 ( 66%)]	Loss: 0.173891
# Epoch:  5 [384000/570624 ( 67%)]	Loss: 0.123978
# Epoch:  5 [390400/570624 ( 68%)]	Loss: 0.098971
# Epoch:  5 [396800/570624 ( 70%)]	Loss: 0.200172
# Epoch:  5 [403200/570624 ( 71%)]	Loss: 0.097551
# Epoch:  5 [409600/570624 ( 72%)]	Loss: 0.281620
# Epoch:  5 [416000/570624 ( 73%)]	Loss: 0.148817
# Epoch:  5 [422400/570624 ( 74%)]	Loss: 0.093326
# Epoch:  5 [428800/570624 ( 75%)]	Loss: 0.076773
# Epoch:  5 [435200/570624 ( 76%)]	Loss: 0.173698
# Epoch:  5 [441600/570624 ( 77%)]	Loss: 0.140577
# Epoch:  5 [448000/570624 ( 79%)]	Loss: 0.121974
# Epoch:  5 [454400/570624 ( 80%)]	Loss: 0.199824
# Epoch:  5 [460800/570624 ( 81%)]	Loss: 0.108824
# Epoch:  5 [467200/570624 ( 82%)]	Loss: 0.259364
# Epoch:  5 [473600/570624 ( 83%)]	Loss: 0.287737
# Epoch:  5 [480000/570624 ( 84%)]	Loss: 0.134951
# Epoch:  5 [486400/570624 ( 85%)]	Loss: 0.129867
# Epoch:  5 [492800/570624 ( 86%)]	Loss: 0.160549
# Epoch:  5 [499200/570624 ( 87%)]	Loss: 0.130487
# Epoch:  5 [505600/570624 ( 89%)]	Loss: 0.149768
# Epoch:  5 [512000/570624 ( 90%)]	Loss: 0.177360
# Epoch:  5 [518400/570624 ( 91%)]	Loss: 0.179572
# Epoch:  5 [524800/570624 ( 92%)]	Loss: 0.218177
# Epoch:  5 [531200/570624 ( 93%)]	Loss: 0.077089
# Epoch:  5 [537600/570624 ( 94%)]	Loss: 0.104665
# Epoch:  5 [544000/570624 ( 95%)]	Loss: 0.192020
# Epoch:  5 [550400/570624 ( 96%)]	Loss: 0.143289
# Epoch:  5 [556800/570624 ( 98%)]	Loss: 0.111250
# Epoch:  5 [563200/570624 ( 99%)]	Loss: 0.191149
# Epoch:  5 [569600/570624 (100%)]	Loss: 0.106400

# %% [markdown]
# ### References
#
# - https://blog.openmined.org/federated-learning-additive-secret-sharing-pysyft/
# - https://www.simonwenkel.com/2019/07/20/introduction-to-pysyft.html
# - https://blog.openmined.org/upgrade-to-federated-learning-in-10-lines/
